# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv('../02_Data/2B_data-output_10.27.1700.csv')

# %%
sns.pairplot(data[['opening_revenue', 'budget', 'runtime', 'num_production_companies']])
plt.show();

# %%
sns.pairplot(data[['opening_revenue', 'budget', 'crew', 'num_production_companies', 
                   'cast_xp_median', 'previous_film_rating']])
plt.show();
